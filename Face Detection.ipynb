# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

path_to_image = os.path.realpath('PictureDetection.jpg')

# %%
img = mpimg.imread(path_to_image)

# %%
img_show = plt.imshow(img)

# %%
img_plt = plt.imread(path_to_image)
img_plt
# Out:
# array([[[180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190],
#         ...,
#         [180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190]],
#
#        [[180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190],
#         ...,
#         [180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190]],
#
#        [[180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190],
#         ...,
#         [180, 183, 190],
#         [180, 183, 190],
#         [180, 183, 190]],
#
#        ...,
#
#        [[ 30,  19,  36],
#         [ 33,  22,  39],
#         [ 39,  28,  45],
#         ...,
#         [ 29,  25,  39],
#         [ 31,  27,  41],
#         [ 32,  28,  42]],
#
#        [[ 29,  18,  35],
#         [ 33,  22,  39],
#         [ 39,  28,  45],
#         ...,
#         [ 30,  26,  40],
#         [ 32,  28,  42],
#         [ 33,  29,  43]],
#
#        [[ 28,  17,  34],
#         [ 37,  26,  43],
#         [ 40,  29,  46],
# ...

# %%
img_plt[0][215]
# Out:
# array([180, 183, 190], dtype=uint8)

# %%
 if (img[x] != img_plt[x]):
        ++i
        System.out.println(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-81b62653331d> in <module>()
# ----> 1 if (img[x] != img_plt[x]):
#       2        ++i
#       3        System.out.println(i)
#
# NameError: name 'x' is not defined

# %%
img_plot = plt.imshow(img_plt)

# %%
from PIL import Image
import face_recognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-1f4e8ccdff7a> in <module>()
#       1 from PIL import Image
# ----> 2 import face_recognition
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
#OpenCV implementation of face detection

# %%
import cv2

# %%
import cv2
import sys
import os

# Get user supplied values
imagePath = os.path.abspath("PictureDetection.jpg")
cascPath = "haarcascade_frontalface_default.xml"

# %%
print(imagePath)
print(cascPath)
# Out:
# C:\Users\JeanBV\Documents\TFLearn_2\TFLearn\PictureDetection.jpg
# haarcascade_frontalface_default.xml

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

# %%
cv2.__version__
# Out:
# '3.4.0'
